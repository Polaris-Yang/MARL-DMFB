# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

# %%
def load_ppo_data(file_path,num=5,maxepoch=100,spacing=5,dataname='alo'):
    fileslist  = os.listdir(file_path)
    rewards, steps, s_rate = None,None,None
    total_data=[]
    for i in range(num):
        for data in fileslist:
            if data.find('rewards')!=-1:
                rewards = np.load(file_path+'/' +data)[i][0:]
            elif data.find('success')!=-1:
                s_rate = np.load(file_path+'/' +data)[i][0:]
            elif data.find('steps')!=-1 :
                steps = np.load(file_path+'/' +data)[i][0:]
        train_epoch = np.arange(1,maxepoch+1,spacing)
        df = pd.DataFrame({'Rewards':rewards,'Success rate':s_rate,'Completion steps':steps,'Evaluation epoch':train_epoch,'repeat':str(i),'schema':dataname})
        total_data.append(df)
    total_data = pd.concat(total_data,axis=0,ignore_index=True)
    return total_data

# %%
sns.set_theme(context='paper', style='whitegrid', font='Arial', font_scale=1.8)
# color = sns.color_palette('Paired',10)
color=[(0.12156862745098039, 0.47058823529411764, 0.7058823529411765),(0.9882352941176471, 0.5529411764705883, 0.3843137254901961)]
sns.palplot(color)
sns.set_palette(color)
print(color)
# Out:
# [(0.12156862745098039, 0.47058823529411764, 0.7058823529411765), (0.9882352941176471, 0.5529411764705883, 0.3843137254901961)]

# %%
vdn2d = load_ppo_data('vdn-2d-1000',maxepoch=10,spacing=1,dataname='VDN')
ppo2d = load_ppo_data('ppo-2d-1000',maxepoch=10,spacing=1,dataname='Baseline')

# %%
data_2d = pd.concat([vdn2d,ppo2d],axis=0,ignore_index=True)
# last  = vdn2d[vdn2d['Train epoch']==100]
# x_app,y_app = append_data(100,400,last)

# %%
fig1, ax1 = plt.subplots(figsize=(5,3), dpi=150)
ax1 =sns.lineplot(x='Evaluation epoch',y='Success rate',hue='schema',data=data_2d)
ax = plt.gca()
ax.set_xticks(range(0,11,1))
ax.set_yticks(np.arange(0,1.1,0.2))
h,l = ax.get_legend_handles_labels()
ax.legend(handles=h,labels=l)

# %%
fig1, ax1 = plt.subplots(figsize=(5,3), dpi=150)
ax1 =sns.lineplot(x='Evaluation epoch',y='Completion steps',hue='schema',data=data_2d)
ax = plt.gca()
ax.set_xticks(range(0,11,1))
# ax.set_yticks(np.arange(0,1.1,0.2))
h,l = ax.get_legend_handles_labels()
ax.legend(handles=h,labels=l)

# %%
vdn3d = load_ppo_data('vdn-3d-1000',maxepoch=10,spacing=1,dataname='VDN')
ppo3d = load_ppo_data('ppo-3d-1000',maxepoch=10,spacing=1,dataname='Baseline')
data_3d = pd.concat([vdn3d,ppo3d],axis=0,ignore_index=True)

# %%
fig1, ax1 = plt.subplots(figsize=(5,3), dpi=150)
ax1 =sns.lineplot(x='Evaluation epoch',y='Success rate',hue='schema',data=data_3d)
ax = plt.gca()
ax.set_xticks(range(0,11,1))
ax.set_yticks(np.arange(0,1.1,0.2))
h,l = ax.get_legend_handles_labels()
ax.legend(handles=h,labels=l)

# %%
fig1, ax1 = plt.subplots(figsize=(5,3), dpi=150)
ax1 =sns.lineplot(x='Evaluation epoch',y='Completion steps',hue='schema',data=data_3d)
ax = plt.gca()
ax.set_xticks(range(0,11,1))
# ax.set_yticks(np.arange(0,1.1,0.2))
h,l = ax.get_legend_handles_labels()
ax.legend(handles=h,labels=l)

# %%
vdn4d = load_ppo_data('vdn-4d',maxepoch=10,spacing=1,dataname='VDN')
ppo4d = load_ppo_data('ppo-4d',maxepoch=10,spacing=1,dataname='Baseline')
data_4d = pd.concat([vdn4d,ppo4d],axis=0,ignore_index=True)

# %%
fig1, ax1 = plt.subplots(figsize=(5,3), dpi=150)
ax1 =sns.lineplot(x='Evaluation epoch',y='Success rate',hue='schema',data=data_4d)
ax = plt.gca()
ax.set_xticks(range(0,11,1))
ax.set_yticks(np.arange(0,1.1,0.2))
h,l = ax.get_legend_handles_labels()
ax.legend(handles=h,labels=l)

# %%
fig1, ax1 = plt.subplots(figsize=(5,3), dpi=150)
ax1 =sns.lineplot(x='Evaluation epoch',y='Completion steps',hue='schema',data=data_4d)
ax = plt.gca()
ax.set_xticks(range(0,11,1))
# ax.set_yticks(np.arange(0,1.1,0.2))
h,l = ax.get_legend_handles_labels()
ax.legend(handles=h,labels=l)
